# %%
pwd
# Out:
# 'D:\\'

# %%
pip install insightface
# Out:
# Requirement already satisfied: insightface in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (0.7.3)
# Requirement already satisfied: numpy in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (1.24.4)
# Requirement already satisfied: onnx in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (1.11.0)
# Requirement already satisfied: tqdm in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (4.67.0)
# Requirement already satisfied: requests in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (2.32.3)
# Requirement already satisfied: matplotlib in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (3.4.3)
# Requirement already satisfied: Pillow in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (10.2.0)
# Requirement already satisfied: scipy in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (1.10.1)
# Requirement already satisfied: scikit-learn in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (1.3.2)
# Requirement already satisfied: scikit-image in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (0.21.0)
# Requirement already satisfied: easydict in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (1.13)
# Requirement already satisfied: cython in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (3.0.11)
# Requirement already satisfied: albumentations in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (1.3.1)
# Requirement already satisfied: prettytable in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from insightface) (3.11.0)
# Requirement already satisfied: PyYAML in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from albumentations->insightface) (6.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from albumentations->insightface) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from albumentations->insightface) (4.10.0.84)
# Requirement already satisfied: networkx>=2.8 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-image->insightface) (2.8.8)
# Requirement already satisfied: imageio>=2.27 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-image->insightface) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-image->insightface) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-image->insightface) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-image->insightface) (24.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-image->insightface) (0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from matplotlib->insightface) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from matplotlib->insightface) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from matplotlib->insightface) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from matplotlib->insightface) (2.9.0)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from onnx->insightface) (3.20.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from onnx->insightface) (4.12.2)
# Requirement already satisfied: wcwidth in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from prettytable->insightface) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from requests->insightface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from requests->insightface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from requests->insightface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from requests->insightface) (2024.6.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-learn->insightface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from scikit-learn->insightface) (3.5.0)
# Requirement already satisfied: colorama in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from tqdm->insightface) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\srmap\anaconda3\envs\newenv\lib\site-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from insightface.app import FaceAnalysis
import torch

# Dataset base path
# dataset_path = r'D:\E Driv Data\DATASETS\CASIA-3D-FACE-DATASET'

dataset_path = r"D:\Face classification\Face DATASETS\105_classes_pins_dataset"

# List class folders named '001', '002', ... '123'
class_names = sorted([d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])
print(f"Found {len(class_names)} classes: {class_names[:5]} ... {class_names[-5:]}")

image_paths = []
labels = []

# Map class name to label index
class_to_idx = {name: idx for idx, name in enumerate(class_names)}

for class_name in class_names:
    class_dir = os.path.join(dataset_path, class_name)
    # Include .bmp extension
    image_files = [f for f in os.listdir(class_dir) if f.lower().endswith(('.jpg', '.jpeg', '.bmp'))]
    print(f"Class '{class_name}': {len(image_files)} images")
    for img_file in image_files:
        image_paths.append(os.path.join(class_dir, img_file))
        labels.append(class_to_idx[class_name])

print(f"Total images found: {len(image_paths)}")

# Initialize insightface FaceAnalysis
providers = ['CUDAExecutionProvider'] if torch.cuda.is_available() else ['CPUExecutionProvider']
app = FaceAnalysis(name='buffalo_l', providers=providers)
app.prepare(ctx_id=0 if torch.cuda.is_available() else -1)
app.det_size = (320, 320)  # Adjust detection size as needed

embedding_list = []
label_list = []
skip_count = 0

print("Extracting embeddings...")
for img_path, label in tqdm(zip(image_paths, labels), total=len(image_paths)):
    img = cv2.imread(img_path)
    if img is None:
        skip_count += 1
        continue
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    faces = app.get(img_rgb)
    if not faces:
        skip_count += 1
        continue

    embedding = faces[0].embedding
    embedding_list.append(embedding)
    label_list.append(label)

print(f"✅ Total valid embeddings extracted: {len(embedding_list)}")
print(f"⚠️ Skipped images (no face detected or load failed): {skip_count}")

if len(embedding_list) == 0:
    raise ValueError("❌ No embeddings extracted. Check dataset images or detection size.")

# Prepare numpy arrays
X = np.array(embedding_list)
y = np.array(label_list)
# Out:
# Found 105 classes: ['pins_Adriana Lima', 'pins_Alex Lawther', 'pins_Alexandra Daddario', 'pins_Alvaro Morte', 'pins_Amanda Crew'] ... ['pins_kiernen shipka', 'pins_margot robbie', 'pins_melissa fumero', 'pins_scarlett johansson', 'pins_tom ellis']
# Class 'pins_Adriana Lima': 213 images
# Class 'pins_Alex Lawther': 152 images
# Class 'pins_Alexandra Daddario': 225 images
# Class 'pins_Alvaro Morte': 139 images
# Class 'pins_Amanda Crew': 117 images
# Class 'pins_Andy Samberg': 196 images
# Class 'pins_Anne Hathaway': 203 images
# Class 'pins_Anthony Mackie': 124 images
# Class 'pins_Avril Lavigne': 162 images
# Class 'pins_Ben Affleck': 126 images
# Class 'pins_Bill Gates': 122 images
# Class 'pins_Bobby Morley': 138 images
# Class 'pins_Brenton Thwaites': 209 images
# Class 'pins_Brian J. Smith': 102 images
# Class 'pins_Brie Larson': 169 images
# Class 'pins_Chris Evans': 166 images
# Class 'pins_Chris Hemsworth': 159 images
# Class 'pins_Chris Pratt': 176 images
# Class 'pins_Christian Bale': 154 images
# Class 'pins_Cristiano Ronaldo': 98 images
# Class 'pins_Danielle Panabaker': 181 images
# Class 'pins_Dominic Purcell': 146 images
# Class 'pins_Dwayne Johnson': 141 images
# Class 'pins_Eliza Taylor': 162 images
# Class 'pins_Elizabeth Lail': 158 images
# Class 'pins_Emilia Clarke': 210 images
# Class 'pins_Emma Stone': 139 images
# Class 'pins_Emma Watson': 211 images
# Class 'pins_Gwyneth Paltrow': 187 images
# Class 'pins_Henry Cavil': 195 images
# Class 'pins_Hugh Jackman': 179 images
# Class 'pins_Inbar Lavi': 127 images
# Class 'pins_Irina Shayk': 156 images
# Class 'pins_Jake Mcdorman': 159 images
# Class 'pins_Jason Momoa': 184 images
# Class 'pins_Jennifer Lawrence': 180 images
# Class 'pins_Jeremy Renner': 167 images
# Class 'pins_Jessica Barden': 141 images
# Class 'pins_Jimmy Fallon': 113 images
# Class 'pins_Johnny Depp': 182 images
# Class 'pins_Josh Radnor': 117 images
# Class 'pins_Katharine Mcphee': 177 images
# Class 'pins_Katherine Langford': 226 images
# Class 'pins_Keanu Reeves': 160 images
# Class 'pins_Krysten Ritter': 171 images
# Class 'pins_Leonardo DiCaprio': 237 images
# Class 'pins_Lili Reinhart': 150 images
# Class 'pins_Lindsey Morgan': 169 images
# Class 'pins_Lionel Messi': 86 images
# Class 'pins_Logan Lerman': 212 images
# Class 'pins_Madelaine Petsch': 192 images
# Class 'pins_Maisie Williams': 193 images
# Class 'pins_Maria Pedraza': 122 images
# Class 'pins_Marie Avgeropoulos': 161 images
# Class 'pins_Mark Ruffalo': 178 images
# Class 'pins_Mark Zuckerberg': 95 images
# Class 'pins_Megan Fox': 209 images
# Class 'pins_Miley Cyrus': 178 images
# Class 'pins_Millie Bobby Brown': 191 images
# Class 'pins_Morena Baccarin': 175 images
# Class 'pins_Morgan Freeman': 105 images
# Class 'pins_Nadia Hilker': 133 images
# Class 'pins_Natalie Dormer': 198 images
# Class 'pins_Natalie Portman': 166 images
# Class 'pins_Neil Patrick Harris': 116 images
# Class 'pins_Pedro Alonso': 125 images
# Class 'pins_Penn Badgley': 171 images
# Class 'pins_Rami Malek': 160 images
# Class 'pins_Rebecca Ferguson': 178 images
# Class 'pins_Richard Harmon': 148 images
# Class 'pins_Rihanna': 133 images
# Class 'pins_Robert De Niro': 156 images
# Class 'pins_Robert Downey Jr': 233 images
# Class 'pins_Sarah Wayne Callies': 159 images
# Class 'pins_Selena Gomez': 186 images
# Class 'pins_Shakira Isabel Mebarak': 154 images
# Class 'pins_Sophie Turner': 204 images
# Class 'pins_Stephen Amell': 159 images
# Class 'pins_Taylor Swift': 131 images
# Class 'pins_Tom Cruise': 192 images
# Class 'pins_Tom Hardy': 198 images
# Class 'pins_Tom Hiddleston': 181 images
# Class 'pins_Tom Holland': 189 images
# Class 'pins_Tuppence Middleton': 133 images
# Class 'pins_Ursula Corbero': 167 images
# Class 'pins_Wentworth Miller': 179 images
# Class 'pins_Zac Efron': 191 images
# Class 'pins_Zendaya': 138 images
# Class 'pins_Zoe Saldana': 186 images
# Class 'pins_alycia dabnem carey': 211 images
# Class 'pins_amber heard': 218 images
# Class 'pins_barack obama': 119 images
# Class 'pins_barbara palvin': 197 images
# Class 'pins_camila mendes': 162 images
# Class 'pins_elizabeth olsen': 221 images
# Class 'pins_ellen page': 188 images
# Class 'pins_elon musk': 135 images
# Class 'pins_gal gadot': 199 images
# Class 'pins_grant gustin': 183 images
# Class 'pins_jeff bezos': 106 images
# Class 'pins_kiernen shipka': 203 images
# Class 'pins_margot robbie': 221 images
# Class 'pins_melissa fumero': 154 images
# Class 'pins_scarlett johansson': 201 images
# Class 'pins_tom ellis': 180 images
# Total images found: 17534
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\SRMAP/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\SRMAP/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\SRMAP/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\SRMAP/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\SRMAP/.insightface\models\buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)
# Extracting embeddings...
#   0%|                                                                               | 12/17534 [00:01<22:53, 12.76it/s]C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\insightface\utils\transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# 100%|████████████████████████████████████████████████████████████████████████████| 17534/17534 [23:58<00:00, 12.19it/s]
# ✅ Total valid embeddings extracted: 1449
# ⚠️ Skipped images (no face detected or load failed): 16085

# %%
# Split data stratified
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# # Train SVM classifier
# clf = SVC(kernel='linear', probability=True)
# clf.fit(X_train, y_train)

# # Predict & evaluate
# y_pred = clf.predict(X_test)
# print("Accuracy:", (y_pred == y_test).mean())
# print("Classification report:\n", classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Accuracy: 0.9379310344827586
# Classification report:
#                               precision    recall  f1-score   support
#
#           pins_Adriana Lima       1.00      1.00      1.00         2
#           pins_Alex Lawther       1.00      1.00      1.00         3
#     pins_Alexandra Daddario       1.00      1.00      1.00         2
#           pins_Alvaro Morte       1.00      1.00      1.00         2
#            pins_Amanda Crew       1.00      1.00      1.00         3
#           pins_Andy Samberg       1.00      1.00      1.00         5
#          pins_Anne Hathaway       1.00      1.00      1.00         3
#         pins_Anthony Mackie       1.00      0.80      0.89         5
#          pins_Avril Lavigne       1.00      1.00      1.00         2
#            pins_Ben Affleck       1.00      1.00      1.00         2
#             pins_Bill Gates       1.00      1.00      1.00         3
#           pins_Bobby Morley       1.00      1.00      1.00         2
#       pins_Brenton Thwaites       1.00      1.00      1.00         2
#         pins_Brian J. Smith       1.00      1.00      1.00         1
#            pins_Brie Larson       1.00      1.00      1.00         3
#            pins_Chris Evans       1.00      1.00      1.00         5
#        pins_Chris Hemsworth       1.00      1.00      1.00         1
#            pins_Chris Pratt       1.00      1.00      1.00         2
#         pins_Christian Bale       1.00      1.00      1.00         1
#      pins_Cristiano Ronaldo       1.00      1.00      1.00         2
#     pins_Danielle Panabaker       1.00      1.00      1.00         2
#        pins_Dominic Purcell       1.00      1.00      1.00         3
#         pins_Dwayne Johnson       1.00      1.00      1.00         3
#           pins_Eliza Taylor       1.00      1.00      1.00         2
#         pins_Elizabeth Lail       1.00      1.00      1.00         2
#          pins_Emilia Clarke       1.00      1.00      1.00         3
#             pins_Emma Stone       1.00      1.00      1.00         2
#            pins_Emma Watson       0.40      1.00      0.57         4
#        pins_Gwyneth Paltrow       1.00      1.00      1.00         3
#            pins_Henry Cavil       1.00      0.50      0.67         2
#           pins_Hugh Jackman       1.00      1.00      1.00         6
#             pins_Inbar Lavi       1.00      1.00      1.00         2
#            pins_Irina Shayk       1.00      1.00      1.00         2
#          pins_Jake Mcdorman       1.00      1.00      1.00         2
#            pins_Jason Momoa       1.00      1.00      1.00         4
#      pins_Jennifer Lawrence       1.00      1.00      1.00         1
#          pins_Jeremy Renner       1.00      0.88      0.93         8
#         pins_Jessica Barden       1.00      1.00      1.00         4
#           pins_Jimmy Fallon       0.80      1.00      0.89         4
#            pins_Johnny Depp       0.00      0.00      0.00         1
#            pins_Josh Radnor       1.00      1.00      1.00         4
#       pins_Katharine Mcphee       1.00      1.00      1.00         2
#     pins_Katherine Langford       1.00      0.75      0.86         4
#           pins_Keanu Reeves       1.00      1.00      1.00         2
#         pins_Krysten Ritter       1.00      1.00      1.00         3
#      pins_Leonardo DiCaprio       0.80      1.00      0.89         4
#          pins_Lili Reinhart       1.00      1.00      1.00         1
#         pins_Lindsey Morgan       1.00      1.00      1.00         2
#           pins_Lionel Messi       1.00      1.00      1.00         2
#           pins_Logan Lerman       1.00      1.00      1.00         3
#       pins_Madelaine Petsch       1.00      1.00      1.00         2
#        pins_Maisie Williams       1.00      1.00      1.00         4
#          pins_Maria Pedraza       1.00      1.00      1.00         3
#     pins_Marie Avgeropoulos       1.00      1.00      1.00         1
#           pins_Mark Ruffalo       0.67      1.00      0.80         2
#        pins_Mark Zuckerberg       1.00      1.00      1.00         1
#              pins_Megan Fox       1.00      1.00      1.00         1
#            pins_Miley Cyrus       1.00      0.67      0.80         3
#     pins_Millie Bobby Brown       1.00      1.00      1.00         3
#        pins_Morena Baccarin       1.00      1.00      1.00         1
#         pins_Morgan Freeman       0.50      1.00      0.67         1
#           pins_Nadia Hilker       1.00      1.00      1.00         3
#         pins_Natalie Dormer       1.00      1.00      1.00         1
#        pins_Natalie Portman       1.00      1.00      1.00         2
#    pins_Neil Patrick Harris       1.00      1.00      1.00         3
#           pins_Pedro Alonso       1.00      1.00      1.00         4
#           pins_Penn Badgley       1.00      1.00      1.00         3
#             pins_Rami Malek       1.00      0.80      0.89         5
#       pins_Rebecca Ferguson       1.00      1.00      1.00         1
#         pins_Richard Harmon       1.00      0.75      0.86         4
#                pins_Rihanna       1.00      1.00      1.00         3
#         pins_Robert De Niro       1.00      1.00      1.00         3
#       pins_Robert Downey Jr       1.00      0.70      0.82        10
#    pins_Sarah Wayne Callies       1.00      1.00      1.00         2
#           pins_Selena Gomez       1.00      1.00      1.00         3
# pins_Shakira Isabel Mebarak       1.00      1.00      1.00         1
#          pins_Sophie Turner       1.00      1.00      1.00         3
#          pins_Stephen Amell       1.00      1.00      1.00         3
#           pins_Taylor Swift       1.00      1.00      1.00         3
#             pins_Tom Cruise       1.00      0.67      0.80         3
#              pins_Tom Hardy       0.50      1.00      0.67         3
#         pins_Tom Hiddleston       0.50      0.80      0.62         5
#            pins_Tom Holland       1.00      1.00      1.00         5
#     pins_Tuppence Middleton       1.00      1.00      1.00         2
#         pins_Ursula Corbero       1.00      0.67      0.80         3
#       pins_Wentworth Miller       1.00      1.00      1.00         1
#              pins_Zac Efron       1.00      0.80      0.89         5
#                pins_Zendaya       1.00      0.67      0.80         3
#            pins_Zoe Saldana       1.00      1.00      1.00         2
#    pins_alycia dabnem carey       1.00      1.00      1.00         3
#            pins_amber heard       1.00      1.00      1.00         1
#           pins_barack obama       1.00      1.00      1.00         3
#         pins_barbara palvin       1.00      1.00      1.00         2
#          pins_camila mendes       1.00      0.50      0.67         2
#        pins_elizabeth olsen       0.67      0.67      0.67         3
#             pins_ellen page       1.00      1.00      1.00         2
#              pins_elon musk       1.00      1.00      1.00         3
#              pins_gal gadot       1.00      1.00      1.00         2
#           pins_grant gustin       1.00      1.00      1.00         3
#             pins_jeff bezos       1.00      1.00      1.00         3
#         pins_kiernen shipka       1.00      1.00      1.00         4
#          pins_margot robbie       1.00      1.00      1.00         4
#         pins_melissa fumero       1.00      1.00      1.00         3
#     pins_scarlett johansson       1.00      1.00      1.00         1
#              pins_tom ellis       1.00      1.00      1.00         2
#
#                    accuracy                           0.94       290
#                   macro avg       0.96      0.95      0.95       290
#                weighted avg       0.96      0.94      0.94       290
# C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# from sklearn.ensemble import RandomForestClassifier

# clf = RandomForestClassifier(n_estimators=100, random_state=42)
# clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# from sklearn.neighbors import KNeighborsClassifier

# clf = KNeighborsClassifier(n_neighbors=5)
# clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=500, random_state=42)
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=500, random_state=42)

# %%
# Predict & evaluate
y_pred = clf.predict(X_test)
print("Accuracy:", (y_pred == y_test).mean())
print("Classification report:\n", classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Accuracy: 0.9275862068965517
# Classification report:
#                               precision    recall  f1-score   support
#
#           pins_Adriana Lima       0.67      1.00      0.80         2
#           pins_Alex Lawther       1.00      1.00      1.00         3
#     pins_Alexandra Daddario       1.00      1.00      1.00         2
#           pins_Alvaro Morte       1.00      1.00      1.00         2
#            pins_Amanda Crew       1.00      1.00      1.00         3
#           pins_Andy Samberg       0.71      1.00      0.83         5
#          pins_Anne Hathaway       1.00      1.00      1.00         3
#         pins_Anthony Mackie       1.00      0.80      0.89         5
#          pins_Avril Lavigne       1.00      1.00      1.00         2
#            pins_Ben Affleck       1.00      1.00      1.00         2
#             pins_Bill Gates       1.00      1.00      1.00         3
#           pins_Bobby Morley       1.00      0.50      0.67         2
#       pins_Brenton Thwaites       1.00      1.00      1.00         2
#         pins_Brian J. Smith       1.00      1.00      1.00         1
#            pins_Brie Larson       1.00      1.00      1.00         3
#            pins_Chris Evans       1.00      1.00      1.00         5
#        pins_Chris Hemsworth       1.00      1.00      1.00         1
#            pins_Chris Pratt       1.00      1.00      1.00         2
#         pins_Christian Bale       0.50      1.00      0.67         1
#      pins_Cristiano Ronaldo       1.00      1.00      1.00         2
#     pins_Danielle Panabaker       1.00      1.00      1.00         2
#        pins_Dominic Purcell       1.00      1.00      1.00         3
#         pins_Dwayne Johnson       1.00      1.00      1.00         3
#           pins_Eliza Taylor       1.00      1.00      1.00         2
#         pins_Elizabeth Lail       1.00      1.00      1.00         2
#          pins_Emilia Clarke       1.00      1.00      1.00         3
#             pins_Emma Stone       1.00      1.00      1.00         2
#            pins_Emma Watson       0.57      1.00      0.73         4
#        pins_Gwyneth Paltrow       1.00      1.00      1.00         3
#            pins_Henry Cavil       1.00      0.50      0.67         2
#           pins_Hugh Jackman       1.00      1.00      1.00         6
#             pins_Inbar Lavi       1.00      1.00      1.00         2
#            pins_Irina Shayk       1.00      1.00      1.00         2
#          pins_Jake Mcdorman       1.00      1.00      1.00         2
#            pins_Jason Momoa       1.00      1.00      1.00         4
#      pins_Jennifer Lawrence       1.00      1.00      1.00         1
#          pins_Jeremy Renner       1.00      0.88      0.93         8
#         pins_Jessica Barden       0.80      1.00      0.89         4
#           pins_Jimmy Fallon       1.00      1.00      1.00         4
#            pins_Johnny Depp       0.00      0.00      0.00         1
#            pins_Josh Radnor       1.00      1.00      1.00         4
#       pins_Katharine Mcphee       1.00      0.50      0.67         2
#     pins_Katherine Langford       1.00      0.75      0.86         4
#           pins_Keanu Reeves       1.00      1.00      1.00         2
#         pins_Krysten Ritter       1.00      1.00      1.00         3
#      pins_Leonardo DiCaprio       0.80      1.00      0.89         4
#          pins_Lili Reinhart       1.00      1.00      1.00         1
#         pins_Lindsey Morgan       1.00      1.00      1.00         2
#           pins_Lionel Messi       1.00      1.00      1.00         2
#           pins_Logan Lerman       0.75      1.00      0.86         3
#       pins_Madelaine Petsch       1.00      1.00      1.00         2
#        pins_Maisie Williams       0.80      1.00      0.89         4
#          pins_Maria Pedraza       1.00      1.00      1.00         3
#     pins_Marie Avgeropoulos       1.00      1.00      1.00         1
#           pins_Mark Ruffalo       1.00      1.00      1.00         2
#        pins_Mark Zuckerberg       0.50      1.00      0.67         1
#              pins_Megan Fox       1.00      1.00      1.00         1
#            pins_Miley Cyrus       1.00      0.67      0.80         3
#     pins_Millie Bobby Brown       0.75      1.00      0.86         3
#        pins_Morena Baccarin       1.00      1.00      1.00         1
#         pins_Morgan Freeman       1.00      1.00      1.00         1
#           pins_Nadia Hilker       1.00      1.00      1.00         3
#         pins_Natalie Dormer       1.00      1.00      1.00         1
#        pins_Natalie Portman       1.00      1.00      1.00         2
#    pins_Neil Patrick Harris       1.00      1.00      1.00         3
#           pins_Pedro Alonso       1.00      1.00      1.00         4
#           pins_Penn Badgley       1.00      1.00      1.00         3
#             pins_Rami Malek       1.00      0.80      0.89         5
#       pins_Rebecca Ferguson       1.00      1.00      1.00         1
#         pins_Richard Harmon       1.00      0.75      0.86         4
#                pins_Rihanna       1.00      1.00      1.00         3
#         pins_Robert De Niro       1.00      1.00      1.00         3
#       pins_Robert Downey Jr       1.00      0.70      0.82        10
#    pins_Sarah Wayne Callies       1.00      1.00      1.00         2
#           pins_Selena Gomez       0.75      1.00      0.86         3
# pins_Shakira Isabel Mebarak       0.50      1.00      0.67         1
#          pins_Sophie Turner       1.00      1.00      1.00         3
#          pins_Stephen Amell       1.00      1.00      1.00         3
#           pins_Taylor Swift       1.00      1.00      1.00         3
#             pins_Tom Cruise       1.00      0.67      0.80         3
#              pins_Tom Hardy       0.75      1.00      0.86         3
#         pins_Tom Hiddleston       0.67      0.80      0.73         5
#            pins_Tom Holland       1.00      1.00      1.00         5
#     pins_Tuppence Middleton       1.00      1.00      1.00         2
#         pins_Ursula Corbero       1.00      0.67      0.80         3
#       pins_Wentworth Miller       0.50      1.00      0.67         1
#              pins_Zac Efron       1.00      0.80      0.89         5
#                pins_Zendaya       1.00      0.67      0.80         3
#            pins_Zoe Saldana       1.00      1.00      1.00         2
#    pins_alycia dabnem carey       1.00      1.00      1.00         3
#            pins_amber heard       1.00      1.00      1.00         1
#           pins_barack obama       1.00      1.00      1.00         3
#         pins_barbara palvin       1.00      1.00      1.00         2
#          pins_camila mendes       1.00      0.50      0.67         2
#        pins_elizabeth olsen       0.67      0.67      0.67         3
#             pins_ellen page       1.00      1.00      1.00         2
#              pins_elon musk       1.00      1.00      1.00         3
#              pins_gal gadot       1.00      1.00      1.00         2
#           pins_grant gustin       1.00      1.00      1.00         3
#             pins_jeff bezos       1.00      1.00      1.00         3
#         pins_kiernen shipka       1.00      1.00      1.00         4
#          pins_margot robbie       1.00      1.00      1.00         4
#         pins_melissa fumero       0.75      1.00      0.86         3
#     pins_scarlett johansson       0.00      0.00      0.00         1
#              pins_tom ellis       1.00      1.00      1.00         2
#
#                    accuracy                           0.93       290
#                   macro avg       0.93      0.93      0.92       290
#                weighted avg       0.94      0.93      0.93       290
# C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SRMAP\anaconda3\envs\newenv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
